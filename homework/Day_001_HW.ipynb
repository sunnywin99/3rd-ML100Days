# %%
#作業一

# %%
#載入所需模組
import numpy as np
import matplotlib.pyplot as plt

# %%
#設定變數
w=3
b=0.5

# %%
#利用模組功能，取得x值的陣列
x_lin = np.linspace(0,100,101)

#利用取亂數方式及陣列的運算，取得y值的陣列
y=(x_lin +np.random.randn(101)*5)*w +b

# %%
#把xy座標畫出來
plt.plot(x_lin,y,'b.',label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc ='upper center')
plt.show()

# %%
#print(x_lin)

# %%
#print(y)

# %%
#yy=np.random.randn(101)
#print(yy)

# %%
#取得另一個y值的陣列(固定的)
y_hat = x_lin*w +b

#畫出點及線
plt.plot(x_lin,y,"b.",label="data")
plt.plot(x_lin,y_hat,'r-',label='prediction')

plt.title("Assume we have data points (And the prediction)")
plt.legend(loc='upper center')
plt.show()

# %%
#定義 MAE(題目提供的)
def mean_absolute_error(y,yp):
    mae=MAE=sum(abs(y-yp))/len(y)
    return mae

# %%
MAE = mean_absolute_error(y,y_hat)
print("The Mean absolute error is %.3f" %(MAE))
# Out:
# The Mean absolute error is 12.123

# %%
#定義 MSE(我們自己定義的)
def mean_square_error(y,yp):
    mse=MSE=(sum((y-yp)**(2))/len(y))
    return mse

# %%
MSE = mean_square_error(y,y_hat)
print("The Mean square error is %.3f" %(MSE))
# Out:
# The Mean square error is 244.088

# %% [markdown]
# 作業二
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# dataset之中的Women's Shoe Prices。
#
# 1. 你選的這組資料為何重要
# →因為它收集了將近1萬多筆網路上賣的女用鞋子的資料。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# →提供者是一間公司，Datafiniti。專門提供大數據的公司。看來是利用爬蟲在網路上各大平台搜集來的。
#
# 3. 蒐集而來的資料型態為何
# →結構化的資料，有相當多欄位。
#
# 4. 這組資料想解決的問題如何評估
# →分類型問題：不同品牌的平均價格是多少？那些品牌價格最高？
# →回歸型問題：特定產品功能的變化與價格有何關聯？

# %% [markdown]
# 作業三
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# →什麼時段，業績比較好？那些區域，業績會比較好？
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# →我覺得如果能夠自行做一個app，記錄客戶叫車的資料，透過這個app來收集資料。
#
# 3. 蒐集而來的資料型態為何
# →結構化的資料。例如：日期、叫車時間、上車時間、上車地點、下車時間、下車地點、客戶姓名、車資、註冊電話、已叫車次數…。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# →從數據表格中，去分析什麼時段叫車的人數較多，可以在該時段建議多人待命。
# →或者是那些區域，比較多人會叫車，也可以多在該區域等待，以增加載客率。
